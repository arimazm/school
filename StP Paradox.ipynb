# %% [markdown]
# # IGA-02. The St. Petersburg Paradox

# %% [markdown]
# **Students**:
# - Prorok Ilya
# - Li Xiran
# - Kocholl Tobias
# - Magomedova Zamira

# %% [markdown]
# **Setup**: In this IGA, in the context of the St. Petersburg Paradox simulation, you are asked to make a script to simulate tosses of a coin until first *tails* occur.

# %% [markdown]
# **Accessories**. To complete this assignment you will need:
#
# 1. Loops **for** and **while**.
# 2. Command **break** to break the **while** loop at some point.
# 3. **np.random.uniform** command (read the help file on this command).
# 4. The **if**...**else** statement.
# 5. Working with commands of **pandas**: *describe()* and *value_counts()* (read the help files on these commands).
# 6. Working with appending elements to lists.

# %%
# %matplotlib notebook

# load the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from scipy import stats

# %% [markdown]
# ## Task 1 (2 points). Write a script (fill in the gaps) to simulate coin tosses

# %%
total_head = []
for i in range(10000): # do this 'number' amount of times
    head_count = 0
    while True:
         flip = np.random.randint(0, 2) #heads = 0, tails = 1
         if (flip == 0):
                head_count += 1 #counting the length of the string of heads
         else:
              break
    total_head.append(head_count) #appending the length of the string to the total_head list
 # 0 means that the first result is tails, so we restart the game

# %% [markdown]
# ## Task 2 (1 point). Construct a histogram of the obtained result

# %%
# transform the np-array into a pandas series
S_pd = pd.Series(total_head)

# making the histogram
S_pd.plot.hist(grid=True, bins=16, rwidth=0.9, color='blue')

# adding labels
plt.title('Histogram for the coin-tossing game')
plt.xlabel('Elements in the series of heads')
plt.ylabel('Frequencies')
plt.grid(axis='y', alpha=0.75)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Task 3 (0.5 points). Give descriptive statistics of the result (min, max, mean, std)

# %%
pd.DataFrame.describe(S_pd) #counting the descriptive statistics
# Out:
# count    10000.000000
# mean         1.032400
# std          1.431487
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          2.000000
# max         16.000000
# dtype: float64

# %% [markdown]
# ## Task 4 (0.5 points). Give distributions of values of the result

# %%
pd.value_counts(S_pd) #building the table of the distribution of values
# Out:
# 0     4845
# 1     2607
# 2     1232
# 3      650
# 4      342
# 5      174
# 6       75
# 7       36
# 8       16
# 10       8
# 9        8
# 11       5
# 12       1
# 16       1
# dtype: int64
